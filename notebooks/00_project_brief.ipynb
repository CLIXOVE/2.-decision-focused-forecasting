# %% [markdown]
# # Project Brief: Decision-Focused Forecasting
#
# Forecasts only matter if they influence decisions.
#
# This project frames forecasting as a decision-support tool,
# not a prediction exercise.
#
# ## Decision Question
# How should inventory buffers change in response to expected demand?
#
# ## Success Criteria
# - Decision logic is explicit and explainable
# - Forecasts change behaviour
# - Outcomes improve relative to a static rule
